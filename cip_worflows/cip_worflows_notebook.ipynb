# %% [markdown]
# # Chest Imaging Platform (CIP) workflows execution

# %% [markdown]
# This notebook walk you through the utilization of 3 different analysis pipelines for Chest CT, using the tools available in the Chest Imaging Platform.

# %% [markdown]
# #### Configuration and data preparation.
# - In order to use the scripts you need to have installed docker on your machine.
# - The input format for the workflows can be a folder with a dicom series, or a NRRD (.nrrd) volume.

# %%
# pull the CIP docker image
# !docker pull acilbwh/chestimagingplatform
# Out:
# Using default tag: latest
# latest: Pulling from acilbwh/chestimagingplatform
# Digest: sha256:f387300b8345975e2dfad65d934adf93723c139b6e7fbb1ff8b7022de88bb526
# Status: Image is up to date for acilbwh/chestimagingplatform:latest
# docker.io/acilbwh/chestimagingplatform:latest

# %%
# install pandas for data visualization
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /Users/rubensanjose/anaconda3/envs/flask/lib/python3.8/site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/rubensanjose/anaconda3/envs/flask/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/rubensanjose/anaconda3/envs/flask/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/rubensanjose/anaconda3/envs/flask/lib/python3.8/site-packages (from pandas) (1.21.0)
# Requirement already satisfied: six>=1.5 in /Users/rubensanjose/anaconda3/envs/flask/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
#print the current path
curr_dir = !pwd
print ("Current path:", curr_dir[-1])
# Out:
# Current path: /Users/rubensanjose/DropboxPartners/BDCatalyst_test

# %% [markdown]
# ### The following cell promt to introduce:
# 1. The name of the dicom folder or NRRD volume to analyze. If this is a folder, the dicom images must be in that folder level and not be in sub-folders. In case it is a NRRD volume the name of the file must be introduced without the .nrrd extension.
# 2. The path where the input folder or NRRD volume is located. This path will be also used to copy all outputs generated on the workflows.

# %%
in_ct = input("Introduce the name of the dicom folder or NRRD volume: ")
work_path = input("Introduce the absolute path where the dicom folder or NRRD volume is: ")
# Out:
# Introduce the name of the dicom folder or NRRD volume: small
# Introduce the absolute path where the dicom folder or NRRD volume is: /Users/rubensanjose/DropboxPartners/BDCatalyst_test

# %% [markdown]
# ## Workflow 1: Densitometry analysis
# This workflow performs a lung segmentation if needed (*_partialLungLabelMap.nrrd) and extract a lung mask with emphysema subtyping (*_localHistogramEmphysema.nrrd).
# Then a densitometry analysis is perfomerd using the lung mask subtyping (*_parenchymaPhenotypes.csv) .

# %%
# This script takes two positional arguments. The name of the dicom folder or nrrd volume and the absolute
# where this folder or file is located.
# !bash cip_densitometry_analysis.sh {in_ct} {work_path}
# Out:
# small.nrrd exists.
# Segmentation already computed.
# Local histogram emphysema masks already computed.
# Densitometry already computed.
# b7c994a2327898e8e8831447c8dfda3c04e875e3624a8da2e5434f81696dd0cd
# b7c994a2327898e8e8831447c8dfda3c04e875e3624a8da2e5434f81696dd0cd

# %%
# display parenchyma phenotypes results
phenotypes = pd.read_csv("small_parenchymaPhenotypes.csv")
drop_list = ['Machine', 'OS_Version', 'Version', 'Generator', 'Run_TimeStamp', 'OS_Kernel', 'OS_Arch', 'OS_Name']
for drop_item in drop_list:
    if drop_item in list(phenotypes.columns):
        phenotypes.drop(drop_item, axis=1, inplace=True)
display(phenotypes)
# Out:
#       CID     Region                            Type    LAA950    LAA925  \
# 0   small  WholeLung                        WildCard  0.010785  0.020563
# 1   small  RightLung                        WildCard  0.012277  0.023616
# 2   small   LeftLung                        WildCard  0.009113  0.017140
# 3   small  WholeLung                NormalParenchyma       NaN       NaN
# 4   small  WholeLung             ParaseptalEmphysema  0.015974  0.027788
# 5   small  WholeLung             PanlobularEmphysema       NaN       NaN
# 6   small  WholeLung      MildCentrilobularEmphysema  0.006243  0.013420
# 7   small  WholeLung  ModerateCentrilobularEmphysema  0.029655  0.057754
# 8   small  WholeLung    SevereCentrilobularEmphysema       NaN       NaN
# 9   small  RightLung                NormalParenchyma       NaN       NaN
# 10  small  RightLung             ParaseptalEmphysema  0.018163  0.031020
# 11  small  RightLung             PanlobularEmphysema       NaN       NaN
# 12  small  RightLung      MildCentrilobularEmphysema  0.006974  0.015587
# 13  small  RightLung  ModerateCentrilobularEmphysema  0.028884  0.058182
# 14  small  RightLung    SevereCentrilobularEmphysema       NaN       NaN
# 15  small   LeftLung                NormalParenchyma       NaN       NaN
# 16  small   LeftLung             ParaseptalEmphysema  0.013400  0.023988
# 17  small   LeftLung             PanlobularEmphysema       NaN       NaN
# 18  small   LeftLung      MildCentrilobularEmphysema  0.005471  0.011133
# 19  small   LeftLung  ModerateCentrilobularEmphysema  0.031126  0.056937
# 20  small   LeftLung    SevereCentrilobularEmphysema       NaN       NaN
#
#       LAA910    LAA905    LAA900    LAA875    LAA856  ...    HUStd500  \
# 0   0.030186  0.034227  0.038877  0.071162  0.108088  ...  100.416342
# 1   0.034944  0.039673  0.045049  0.082341  0.124180  ...  103.205843
# 2   0.024851  0.028120  0.031956  0.058628  0.090045  ...   96.930788
# 3        NaN       NaN       NaN       NaN       NaN  ...         NaN
# 4   0.038303  0.042407  0.047035  0.076386  0.106802  ...  111.991924
# 5        NaN       NaN       NaN       NaN       NaN  ...         NaN
# 6   0.021381  0.024969  0.029163  0.060601  0.099558  ...   93.312209
# 7   0.082931  0.092975  0.104123  0.174861  0.243253  ...  101.997293
# 8        NaN       NaN       NaN       NaN       NaN  ...         NaN
# 9        NaN       NaN       NaN       NaN       NaN  ...         NaN
# 10  0.042553  0.047084  0.051896  0.083523  0.115552  ...  116.471530
# 11       NaN       NaN       NaN       NaN       NaN  ...         NaN
# 12  0.025320  0.029663  0.034736  0.072237  0.117711  ...   95.511048
# 13  0.084814  0.095145  0.107108  0.180748  0.252162  ...   98.736575
# 14       NaN       NaN       NaN       NaN       NaN  ...         NaN
# 15       NaN       NaN       NaN       NaN       NaN  ...         NaN
# 16  0.033305  0.036907  0.041321  0.067994  0.096514  ...  106.649222
# 17       NaN       NaN       NaN       NaN       NaN  ...         NaN
# 18  0.017222  0.020013  0.023279  0.048317  0.080393  ...   90.517183
# 19  0.079336  0.088830  0.098423  0.163617  0.226241  ...  107.602666
# 20       NaN       NaN       NaN       NaN       NaN  ...         NaN
#
#     HUKurtosis500  HUSkewness500  HUMode500  HUMedian500  HUMin500  HUMax500  \
# 0       -0.190469       0.308117     -779.0       -760.0   -1417.0    -501.0
# 1       -0.246224       0.369451     -793.0       -768.0   -1333.0    -501.0
# 2       -0.095395       0.250045     -773.0       -753.0   -1417.0    -501.0
# 3             NaN            NaN        NaN          NaN       NaN       NaN
# 4       -0.452694       0.144603     -801.0       -753.0   -1417.0    -501.0
# 5             NaN            NaN        NaN          NaN       NaN       NaN
# 6       -0.100904       0.397799     -773.0       -760.0   -1301.0    -501.0
# 7        0.190996       0.537894     -799.0       -801.0   -1253.0    -501.0
# 8             NaN            NaN        NaN          NaN       NaN       NaN
# 9             NaN            NaN        NaN          NaN       NaN       NaN
# 10      -0.575895       0.149291     -791.0       -756.0   -1333.0    -501.0
# 11            NaN            NaN        NaN          NaN       NaN       NaN
# 12      -0.119766       0.476413     -796.0       -769.0   -1193.0    -501.0
# 13       0.241996       0.545985     -799.0       -804.0   -1185.0    -501.0
# 14            NaN            NaN        NaN          NaN       NaN       NaN
# 15            NaN            NaN        NaN          NaN       NaN       NaN
# 16      -0.301862       0.140364     -801.0       -751.0   -1417.0    -501.0
# 17            NaN            NaN        NaN          NaN       NaN       NaN
# 18      -0.033116       0.329050     -773.0       -752.0   -1301.0    -501.0
# 19       0.049753       0.495402     -838.0       -795.0   -1253.0    -501.0
# 20            NaN            NaN        NaN          NaN       NaN       NaN
#
#       Volume        Mass  TypeFrac
# 0   1.185513  385.380135  1.000000
# 1   0.626634  202.250747  1.000000
# 2   0.558879  183.129388  1.000000
# 3   0.000000         NaN  0.000000
# 4   0.381286  151.051500  0.321621
# 5   0.000000         NaN  0.000000
# 6   0.705727  197.770118  0.595292
# 7   0.062428   14.622498  0.052659
# 8   0.000000         NaN  0.000000
# 9   0.000000         NaN  0.000000
# 10  0.206043   82.872881  0.328808
# 11  0.000000         NaN  0.000000
# 12  0.362429   99.574225  0.578374
# 13  0.040972    9.420181  0.065384
# 14  0.000000         NaN  0.000000
# 15  0.000000         NaN  0.000000
# 16  0.175244   68.178619  0.313563
# 17  0.000000         NaN  0.000000
# 18  0.343298   98.195893  0.614261
# 19  0.021456    5.202318  0.038390
# 20  0.000000         NaN  0.000000
#
# [21 rows x 43 columns]

# %% [markdown]
# ## Workflow 2: Vascular analysis
# This workflow performs a lung segmentation if needed (_partialLungLabelMap.nrrd) and extract a vessel particles tree (_wholeLungVesselParticles.vtk) then compute several vascular phenotypes from the particles information (_vasculaPhenotypes.csv).

# %%
# This script takes two positional arguments. The name of the dicom folder or nrrd volume and the absolute
# where this folder or file is located.
# !bash cip_vascular_analysis.sh {in_ct} {work_path}
# Out:
# small.nrrd exists.
# Segmentation already computed.
# Vessel particles already computed.
# Vascular phenotypes already computed.
# 3cf22710b08126a17fb346110460a145e31b81c01b1809ff9e3a30f6560d0763
# 3cf22710b08126a17fb346110460a145e31b81c01b1809ff9e3a30f6560d0763

# %%
# display vascular phenotypes results
vascular = pd.read_csv("small_vascularPhenotypes.csv")
drop_list = ['Machine', 'OS_Version', 'Version', 'Generator', 'Run_TimeStamp', 'OS_Kernel', 'OS_Arch', 'OS_Name']
for drop_item in drop_list:
    if drop_item in list(vascular.columns):
        vascular.drop(drop_item, axis=1, inplace=True)
display(vascular)
# Out:
#      CID     Region    Type           TBV          BV5        BV5_10  \
# 0  small  WholeLung  Vessel  51113.523522  7885.326788  10313.610940
# 1  small  RightLung  Vessel  27863.114881  3809.964198   5401.769305
# 2  small   LeftLung  Vessel  23464.287832  3519.655070   5379.121624
#
#        BV10_15      BV15_20      BV20_25      BV25_30  ...      BV40_45  \
# 0  5902.875237  3756.114934  2465.274555  1647.859395  ...  1741.593646
# 1  3025.048609  2020.316357  1379.610740  1035.450700  ...  1165.691807
# 2  3050.533424  1800.632405  1118.962687   654.609344  ...   553.115830
#
#        BV45_50     BV50_55      BV55_60      BV60_65      BV65_70     BV70_75  \
# 0  1456.106349  957.506750  1326.885152  1721.656120  1452.015290  902.279664
# 1  1075.125403  752.865884   881.574899   902.301593   654.386180  291.952549
# 2   379.241815  235.278603   439.023910   804.294586   788.663728  629.672721
#
#       BV75_80      BV80_85      BV85_90
# 0  921.962562  3905.787124  1250.684363
# 1  461.821604  2077.954582   880.018268
# 2  579.488967  1546.618412   520.865454
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Workflow 3: Airway analysis
# This workflow performs a lung segmentation if needed (*_partialLungLabelMap.nrrd) and extract an aorway particles tree (*_wholeLungAirwayParticles.vtk) then compute several airway phenotypes from the particles information (*_airwayPhenotypes.csv).

# %%
# This script takes two positional arguments. The name of the dicom folder or nrrd volume and the absolute
# where this folder or file is located.
# !bash cip_airway_analysis.sh {in_ct} {work_path}
# Out:
# small.nrrd exists.
# Segmentation already computed.
# Airway particles already computed.
# Airway phenotypes already computed.
# dd881fb41a2980f805c9984a6290dc3018a632562a841ca8ea99484fc929fffe
# dd881fb41a2980f805c9984a6290dc3018a632562a841ca8ea99484fc929fffe

# %%
# display airway phenotypes results
airway = pd.read_csv("small_airwayPhenotypes.csv")
drop_list = ['Machine', 'OS_Version', 'Version', 'Generator', 'Run_TimeStamp', 'OS_Kernel', 'OS_Arch', 'OS_Name']
for drop_item in drop_list:
    if drop_item in list(airway.columns):
        airway.drop(drop_item, axis=1, inplace=True)
display(airway)
# Out:
#      CID     Region    Type  innerRadius  outerRadius  wallThickness  \
# 0  small  WholeLung  Airway     2.289828     3.418612       1.128784
# 1  small   LeftLung  Airway     2.172343     3.298077       1.125735
# 2  small  RightLung  Airway     2.365314     3.496058       1.130744
#
#    innerPerimeter  outerPerimeter  innerArea  outerArea  ...  wallAreaPerc  \
# 0       15.105052       22.147011  24.287336  44.582918  ...     60.035193
# 1       14.388286       21.391551  22.186637  41.500273  ...     61.484100
# 2       15.565589       22.632408  25.637077  46.563579  ...     59.104241
#
#        Pi10      Pi15  wallIntensity  peakWallIntensity  innerWallIntensity  \
# 0  3.818951  4.400011            NaN                NaN                 NaN
# 1  3.824384  4.366444      485.91494         516.594903          372.400727
# 2  3.814821  4.418329            NaN                NaN                 NaN
#
#    outerWallIntensity       power  numPointsTotal  numPointsAfterExclusion
# 0                 NaN         NaN          4200.0                   4200.0
# 1          441.859446  329.745015          1644.0                   1644.0
# 2                 NaN         NaN          2556.0                   2556.0
#
# [3 rows x 21 columns]
